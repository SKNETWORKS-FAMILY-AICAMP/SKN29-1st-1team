# %%
import requests
import os
import dotenv

dotenv.load_dotenv(override=True)

BASE_URL = 'http://apis.data.go.kr/6280000/ICRoadStat_v2/STAT-Speed_DD_Road'
SERVICE_KEY = os.getenv('PUBLIC_DATA_API_KEY')
MAX_PAGE_SIZE = 3000
print(f"[INFO] base_url={BASE_URL}, serviceKey={SERVICE_KEY[:5]}..., MAX_PAGE_SIZE={MAX_PAGE_SIZE}")

# %% [markdown]
# ```
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#   'body': {'totalCount': 186,
#    'items': [{'statDate': '20260101',
#      'roadName': '가정로',
#      'direction': '상행',
#      'dayStatValue': '20',
#      'hour00': '21',
#      'hour01': '20',
#      'hour02': '22',
#      'hour03': '24',
#      'hour04': '23',
#      'hour05': '23',
#      'hour06': '21',
#      'hour07': '20',
#      'hour08': '19',
#      'hour09': '20',
#      'hour10': '19',
#      'hour11': '19',
#      'hour12': '18',
#      'hour13': '18',
#      'hour14': '17',
#      'hour15': '17',
#      'hour16': '17',
#      'hour17': '16',
#      'hour18': '17',
# ...
#      'hour21': '37',
#      'hour22': '36',
#      'hour23': '37'}],
#    'pageNo': 1,
#    'numOfRows': 3000}}}
#    ```

# %%
import pandas as pd

def get_trafic_speed_json(YMD, pageNo=1, numOfRows=MAX_PAGE_SIZE):
    params = {'serviceKey': SERVICE_KEY, 'pageNo': pageNo, 'numOfRows': numOfRows, 'YMD': YMD}
    return requests.get(BASE_URL, params).json()

def extract_items(response_json):
    items = response_json["response"]["body"]["items"]
    processed = []
    for item in items:
        new_item = {}
        for k, v in item.items():
            if k.startswith("hour"):
                new_item[k] = int(v)
            else:
                new_item[k] = v
        processed.append(new_item)
    return processed

# %%
import mysql.connector as mc 
from mysql.connector import Error
import dotenv
import os
from datetime import datetime, timedelta

dotenv.load_dotenv()

DB_CONFIG = {
        'host': os.getenv('DB_HOST'),
        'port': int(os.getenv('DB_PORT', 3306)),
        'user': os.getenv('DB_USER'),
        'password': os.getenv('DB_PASSWORD'),
        'database': os.getenv('DB_DATABASE'),
        'autocommit': False,
}
print_config = {key: DB_CONFIG[key] if key != 'password' else '****' for key in DB_CONFIG}
print(f"[INFO] DB_CONFIG={print_config}")

columns = [
    'statDate', 'roadName', 'direction', 'dayStatValue'
] + [f"hour{str(i).zfill(2)}" for i in range(24)]
col_str = ", ".join(columns)

# %s, %s, ...
placeholders = ", ".join(["%s"] * len(columns))

insert_query = f"""
INSERT INTO traffic_speed_raw ({col_str})
VALUES ({placeholders})
"""
insert_query

# %%
import mysql.connector as mc

create_query = """
CREATE TABLE IF NOT EXISTS traffic_speed_raw (
    id BIGINT AUTO_INCREMENT PRIMARY KEY,

    statDate DATE NOT NULL,
    roadName VARCHAR(100),
    direction VARCHAR(10) NOT NULL,
    dayStatValue int,

    hour00 INT, hour01 INT, hour02 INT,
    hour03 INT, hour04 INT, hour05 INT,
    hour06 INT, hour07 INT, hour08 INT,
    hour09 INT, hour10 INT, hour11 INT,
    hour12 INT, hour13 INT, hour14 INT,
    hour15 INT, hour16 INT, hour17 INT,
    hour18 INT, hour19 INT, hour20 INT,
    hour21 INT, hour22 INT, hour23 INT,

    UNIQUE KEY uniq_traffic (statDate, roadName, direction)
);
"""

conn = mc.connect(**DB_CONFIG)
cursor = conn.cursor()

try:
    cursor.execute(create_query)
    conn.commit()
    print("[INFO] traffic_raw 테이블 생성 완료")
except Exception as e:
    print(f"[ERROR] 테이블 생성 실패: {e}")
    conn.rollback()

cursor.close()
conn.close()

# %%
import mysql.connector as mc
from mysql.connector import Error

conn = mc.connect(**DB_CONFIG)
cursor = conn.cursor()

def generate_dates(year, m=1, d=1):
    start = datetime(year, m, d)
    end = datetime(year, 12, 31)
    while start <= end:
        yield start.strftime("%Y%m%d")
        start += timedelta(days=1)

def dict_to_tuple(item):
    return tuple(item[col] for col in columns)

total_inserted = 0

for date in generate_dates(2025):
    print(f"[INFO] Processing {date}")

    try:
        # 1️⃣ API 호출
        json_data = get_trafic_speed_json(date)

        # 2️⃣ 데이터 추출
        items = extract_items(json_data)

        if not items:
            print(f"[WARN] No data for {date}")
            continue

        # 3️⃣ dict → tuple 변환
        values = [dict_to_tuple(item) for item in items]

        # 4️⃣ insert
        cursor.executemany(insert_query, values)

        # 5️⃣ commit
        conn.commit()

        total_inserted += len(values)
        print(f"[INFO] Inserted {len(values)} rows")

    except Exception as e:
        print(f"[ERROR] {date}: {e}")
        conn.rollback()

cursor.close()
conn.close()

print(f"[DONE] Total inserted: {total_inserted}")
