# %%
# 데이터베아스 인증키
import requests
import xml.etree.ElementTree as ET
import os
from dotenv import load_dotenv
load_dotenv()

service_key = os.getenv('drive_flow')
url = 'http://apis.data.go.kr/6280000/ICRoadVolStat'

print()
